# %%
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Have a lot of information when use violinplot than boxplot

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='smoker', split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# add 'jitter': True or False to see difference
# We can usually add 'hue', 'split'
sns.stripplot(x='day', y='total_bill', data=tips, jitter=True, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### swarmplot is combine: violin plot + strip plot => beautiful
# - For large data: not useful --> because of lot of information

# %%
sns.swarmplot(x='day', y='total_bill', data=tips, hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### combine violin plot & swarmplot: just demo

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
sns.swarmplot(x='day', y='total_bill', data=tips,color='yellow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### We can call other kind of splot above by this method

# %%
sns.factorplot(x='day', y='total_bill', data=tips, kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 sns.factorplot(x='day', y='total_bill', data=tips, kind='bar')
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'
