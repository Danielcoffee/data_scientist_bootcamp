# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### set style
# - while, ticks, darkgrid, whitegrid,...
# - or we can use figure

# %%
sns.set_style('white')
sns.countplot(data=tips, x='sex')
sns.despine(left=True, bottom=True) # remove top & right line by default

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='sex', data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# ### scale
# - set_context: 'poster', 'notebook', ....
# - font_scale

# %%
sns.set_context('poster', font_scale=1)
sns.countplot(x='sex', data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# lot of color of palette to choice: google
sns.set_context('notebook', font_scale=1)

sns.lmplot(x='total_bill', y='tip', data=tips, palette='cool', hue='sex')
